# %% [markdown]
# ## Train a Mask R-CNN model on dentex image data ##
#
# Model description for the "mask_rcnn_X_101_32x8d_FPN_3x.yaml" model:
#
# https://github.com/facebookresearch/detectron2/blob/main/MODEL_ZOO.md
#
# Weights configuration file:
#
# configs/COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x.yaml
#
# This notebooks requires the detectron2 library.

# %%
# Imports
import os
import numpy as np
import pandas as pd
import json
import glob
from matplotlib import pyplot as plt
from pathlib import Path

# Appearance of the Notebook
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
np.set_printoptions(linewidth=110)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

# PyTorch libraries
import torch

# Detectron2 library
import detectron2
from detectron2 import model_zoo
from detectron2.config import get_cfg
from detectron2.structures import BoxMode
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# Import this module with autoreload
# %load_ext autoreload
# %autoreload 2
import dentexmodel as dm
from dentexmodel.imageproc import ImageData
from dentexmodel.detector import Trainer

print(f'Project module version: {dm.__version__}')
print(f'Detectron2 version:     {detectron2.__version__}')
# Out:
# <style>.container { width:100% !important; }</style>
# Project module version: 0.0.post1.dev163+g9fa083d.d20240224
# Detectron2 version:     0.6

# %%
# GPU checks
is_cuda = torch.cuda.is_available()
print(f'CUDA available: {is_cuda}')
print(f'Number of GPUs found:  {torch.cuda.device_count()}')

if is_cuda:
    print(f'Current device ID:     {torch.cuda.current_device()}')
    print(f'GPU device name:       {torch.cuda.get_device_name(0)}')
    print(f'CUDNN version:         {torch.backends.cudnn.version()}')
    device_str = 'cuda:0'
    torch.cuda.empty_cache() 
else:
    device_str = 'cpu'
device = torch.device(device_str)
print()
print(f'Device for model training/inference: {device}')
# Out:
# CUDA available: True
# Number of GPUs found:  1
# Current device ID:     0
# GPU device name:       NVIDIA GeForce RTX 3070 Laptop GPU
# CUDNN version:         8902
#
# Device for model training/inference: cuda:0

# %%
# Path settings 
# Main data directory (defined as environment variable in docker-compose.yml)
data_root = os.environ.get('DATA_ROOT')

# Download directory (change as needed)
dentex_dir = os.path.join(data_root, 'dentex')
model_dir = os.path.join(data_root, 'model')
data_dir = os.path.join(dentex_dir, 'dentex_detection')

# This image directory is where the xrays are in the archive, so should be left as-is
image_dir = os.path.join(data_dir, 'quadrant_enumeration', 'xrays')

# Directory for the output
output_dir = os.path.join(data_dir, 'output')

# Data frame with data splits 
data_df_file_name = 'dentex_detection_datasplit.parquet'
data_df_file = os.path.join(data_dir, data_df_file_name)

# %%
# Annotation files (and make sure the files are where they should be.
annotation_files = {}
dataset_list = ['train', 'val', 'test']
annotation_name_list = [f'dentex_detection_{dataset}.json' for dataset in dataset_list]
annotation_file_list = [os.path.join(data_dir, file_name) for file_name in annotation_name_list]
annotation_file_dict = dict(zip(dataset_list, annotation_file_list))
for dataset, annotation_file in annotation_file_dict.items():
    if not os.path.exists(annotation_file):
        raise FileNotFoundError(f'Annotation "{json_file}" not found.')
    else:
        annotation_files.update({dataset: annotation_file})
display(annotation_files)
# Out:
# {'train': '/app/data/dentex/dentex_detection/dentex_detection_train.json',
#  'val': '/app/data/dentex/dentex_detection/dentex_detection_val.json',
#  'test': '/app/data/dentex/dentex_detection/dentex_detection_test.json'}

# %% [markdown]
# ### Register the dentex datasets ####

# %%
annotation_dict = {}
for dataset, annotation_file in annotation_file_dict.items():
    try:
        with open(annotation_file, 'r') as fl:
            annotations = json.load(fl)
    except FileNotFoundError:
        print(f'Annotation file not found: {annotation_file}')
        print('Make sure to run the annotations notebook.')
    else:
        annotation_dict.update({dataset: annotations})
        print(f'Loaded annotations for {len(annotations)} images for dataset "{dataset}".')

# Register the data sets
for dataset in dataset_list:
    dataset_name = f'dentex_{dataset}'
    if dataset_name not in DatasetCatalog:
        DatasetCatalog.register(name=dataset_name, func=lambda d=dataset: annotation_dict.get(d))
        MetadataCatalog.get(dataset_name).set(thing_classes=['tooth'])
# Out:
# Loaded annotations for 534 images for dataset "train".
# Loaded annotations for 50 images for dataset "val".
# Loaded annotations for 50 images for dataset "test".

# %%
# Plot one image from the training set
def show_image(image, figsize=(3, 3), title=''):
    fig, ax = plt.subplots(figsize=figsize)
    ax.imshow(image)
    ax.set_title(title)
    ax.set(xticks=[], yticks=[])
    return fig, ax

# Load one random image from the training set
dataset = 'dentex_train'
image_list = DatasetCatalog.get(dataset)
image_dict = np.random.choice(image_list, size=1)[0]
metadata = MetadataCatalog.get(dataset)
im = ImageData().load_image(image_dict.get('file_name'))
vs = Visualizer(img_rgb=im, metadata=metadata, scale = 1.0)
vs = vs.draw_dataset_dict(image_dict).get_image()
fig, ax = show_image(vs, figsize=(12, 3), title=f'Example image from dataset "{dataset}"')
plt.show()

# %% [markdown]
# ### Configure Faster R-CNN model for training ###

# %%
# Model definition
# For a description, see https://github.com/facebookresearch/detectron2/blob/main/MODEL_ZOO.md
# configs/COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x.yaml
# configs/COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml
model_config = os.path.join('COCO-InstanceSegmentation', 'mask_rcnn_R_101_FPN_3x.yaml')

# Build configuration file
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file(model_config))

# Output directory
model_name = 'Toothsegment'
model_version = 1
model_output_dir = os.path.join(model_dir, model_name, f'version_{model_version}')
Path(model_output_dir).mkdir(parents=True, exist_ok=True)

# Set the names for the datasets (as registered)
cfg.DATASETS.TRAIN = ('dentex_train', )
cfg.DATASETS.TEST = ('dentex_val', )
cfg.TEST.EVAL_PERIOD = 100
# The numbers of workers you can use depends on the number of cores and memory available per core
# Four workes is good for 32G memory
cfg.DATALOADER.NUM_WORKERS = 4
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(model_config)
# The batch size needs to be adjusted according to the GPU memory
# A batch size of 4 works for and 8 GB GPU
cfg.SOLVER.IMS_PER_BATCH = 4
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.STEPS = []
# Train for at least 3,000 iterations to get good results
cfg.SOLVER.MAX_ITER = 1000
cfg.SOLVER.CHECKPOINT_PERIOD = 500
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1
cfg.OUTPUT_DIR = model_output_dir

# Train on GPU or CPU
cfg.MODEL.DEVICE = device.type

# Save the config file before training
model_config_file_name = f'{model_name}_{model_version}_config.yml'
model_config_file = os.path.join(model_output_dir, model_config_file_name)
with open(model_config_file, mode='w') as fl:
    fl.write(cfg.dump())

# %%
# Train the model
trainer = Trainer(cfg)
trainer.resume_or_load(resume=True)
trainer.train()
# Out:
# [02/26 16:09:29 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [02/26 16:09:29 d2.data.build]: Removed 0 images with no usable annotations. 534 images left.
# [02/26 16:09:29 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   tooth    | 15242        |
# |            |              |
# [02/26 16:09:29 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/26 16:09:29 d2.data.build]: Using training sampler TrainingSampler
# [02/26 16:09:29 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 16:09:29 d2.data.common]: Serializing 534 elements to byte tensors and concatenating them all ...
# [02/26 16:09:29 d2.data.common]: Serialized dataset takes 2.24 MiB
# [02/26 16:09:29 d2.data.build]: Making batched data loader with batch_size=4
# [02/26 16:09:29 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/26 16:09:29 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   tooth    | 1408         |
# |            |              |
# [02/26 16:09:29 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 16:09:29 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/26 16:09:29 d2.data.common]: Serialized dataset takes 0.21 MiB
# [02/26 16:09:29 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x/138205316/model_final_a3ec72.pkl ...
# model_final_a3ec72.pkl: 254MB [00:02, 106MB/s]
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (2, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (1, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (1,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [02/26 16:09:32 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [02/26 16:09:46 d2.utils.events]:  eta: 0:11:06  iter: 19  total_loss: 4.591  loss_cls: 0.6808  loss_box_reg: 0.7072  loss_mask: 0.6944  loss_rpn_cls: 2.32  loss_rpn_loc: 0.2528    time: 0.6649  last_time: 0.6253  data_time: 0.0189  last_data_time: 0.0049   lr: 4.9953e-06  max_mem: 5400M
# 2024-02-26 16:09:46.845901: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 16:09:46.845928: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 16:09:46.846648: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 16:09:46.851656: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 16:09:47.495542: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [02/26 16:10:00 d2.utils.events]:  eta: 0:10:24  iter: 39  total_loss: 2.725  loss_cls: 0.6454  loss_box_reg: 0.824  loss_mask: 0.6922  loss_rpn_cls: 0.335  loss_rpn_loc: 0.2216    time: 0.6545  last_time: 0.6293  data_time: 0.0054  last_data_time: 0.0056   lr: 9.9902e-06  max_mem: 5400M
# [02/26 16:10:13 d2.utils.events]:  eta: 0:10:11  iter: 59  total_loss: 2.459  loss_cls: 0.6081  loss_box_reg: 0.8529  loss_mask: 0.6872  loss_rpn_cls: 0.08212  loss_rpn_loc: 0.2199    time: 0.6529  last_time: 0.6480  data_time: 0.0058  last_data_time: 0.0053   lr: 1.4985e-05  max_mem: 5400M
# [02/26 16:10:26 d2.utils.events]:  eta: 0:09:58  iter: 79  total_loss: 2.369  loss_cls: 0.5766  loss_box_reg: 0.8193  loss_mask: 0.6807  loss_rpn_cls: 0.07627  loss_rpn_loc: 0.2133    time: 0.6517  last_time: 0.6766  data_time: 0.0054  last_data_time: 0.0048   lr: 1.998e-05  max_mem: 5400M
# [02/26 16:10:40 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 16:10:40 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 16:10:40 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/26 16:10:40 d2.data.common]: Serialized dataset takes 0.21 MiB
# [02/26 16:10:40 d2.evaluation.coco_evaluation]: Trying to convert 'dentex_val' to COCO format ...
# [02/26 16:10:40 d2.data.datasets.coco]: Converting annotations of dataset 'dentex_val' to COCO format ...)
# [02/26 16:10:40 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [02/26 16:10:40 d2.data.datasets.coco]: Conversion finished, #images: 50, #annotations: 1408
# [02/26 16:10:40 d2.data.datasets.coco]: Caching COCO format annotations at '/app/data/model/Toothsegment/version_1/eval/dentex_val_coco_format.json' ...
# [02/26 16:10:40 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/26 16:10:48 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0007 s/iter. Inference: 0.1323 s/iter. Eval: 0.5516 s/iter. Total: 0.6846 s/iter. ETA=0:00:26
# [02/26 16:10:53 d2.evaluation.evaluator]: Inference done 19/50. Dataloading: 0.0008 s/iter. Inference: 0.1407 s/iter. Eval: 0.5423 s/iter. Total: 0.6839 s/iter. ETA=0:00:21
# [02/26 16:10:59 d2.evaluation.evaluator]: Inference done 27/50. Dataloading: 0.0008 s/iter. Inference: 0.1328 s/iter. Eval: 0.5477 s/iter. Total: 0.6815 s/iter. ETA=0:00:15
# [02/26 16:11:04 d2.evaluation.evaluator]: Inference done 35/50. Dataloading: 0.0009 s/iter. Inference: 0.1287 s/iter. Eval: 0.5413 s/iter. Total: 0.6710 s/iter. ETA=0:00:10
# [02/26 16:11:09 d2.evaluation.evaluator]: Inference done 44/50. Dataloading: 0.0009 s/iter. Inference: 0.1289 s/iter. Eval: 0.5299 s/iter. Total: 0.6598 s/iter. ETA=0:00:03
# [02/26 16:11:13 d2.evaluation.evaluator]: Total inference time: 0:00:29.743560 (0.660968 s / iter per device, on 1 devices)
# [02/26 16:11:13 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:05 (0.127358 s / iter per device, on 1 devices)
# [02/26 16:11:13 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 16:11:13 d2.evaluation.coco_evaluation]: Saving results to /app/data/model/Toothsegment/version_1/eval/coco_instances_results.json
# [02/26 16:11:13 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/26 16:11:13 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/26 16:11:13 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [02/26 16:11:13 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/26 16:11:13 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.291
# [02/26 16:11:13 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |  AP   |  AP50  |  AP75  |  APs  |  APm  |  APl  |
# |:-----:|:------:|:------:|:-----:|:-----:|:-----:|
# | 5.700 | 18.618 | 1.359  |  nan  | 2.049 | 6.904 |
# [02/26 16:11:13 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/26 16:11:13 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/26 16:11:13 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 16:11:13 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 16:11:13 d2.evaluation.testing]: copypaste: 5.7001,18.6180,1.3593,nan,2.0493,6.9038
# [02/26 16:11:18 d2.utils.events]:  eta: 0:09:46  iter: 99  total_loss: 2.322  loss_cls: 0.5555  loss_box_reg: 0.8361  loss_mask: 0.6701  loss_rpn_cls: 0.06912  loss_rpn_loc: 0.193  validation_loss: 2.342    time: 0.6532  last_time: 0.6329  data_time: 0.0054  last_data_time: 0.0049   lr: 2.4975e-05  max_mem: 5400M
# [02/26 16:11:31 d2.utils.events]:  eta: 0:09:35  iter: 119  total_loss: 2.29  loss_cls: 0.5351  loss_box_reg: 0.8512  loss_mask: 0.6583  loss_rpn_cls: 0.05697  loss_rpn_loc: 0.187  validation_loss: 2.342    time: 0.6544  last_time: 0.7018  data_time: 0.0053  last_data_time: 0.0053   lr: 2.997e-05  max_mem: 5400M
# [02/26 16:11:44 d2.utils.events]:  eta: 0:09:22  iter: 139  total_loss: 2.241  loss_cls: 0.5171  loss_box_reg: 0.8309  loss_mask: 0.6414  loss_rpn_cls: 0.0526  loss_rpn_loc: 0.1861  validation_loss: 2.342    time: 0.6549  last_time: 0.6605  data_time: 0.0052  last_data_time: 0.0051   lr: 3.4965e-05  max_mem: 5400M
# [02/26 16:11:57 d2.utils.events]:  eta: 0:09:09  iter: 159  total_loss: 2.171  loss_cls: 0.4926  loss_box_reg: 0.8297  loss_mask: 0.6261  loss_rpn_cls: 0.05984  loss_rpn_loc: 0.1805  validation_loss: 2.342    time: 0.6545  last_time: 0.6609  data_time: 0.0052  last_data_time: 0.0050   lr: 3.996e-05  max_mem: 5400M
# [02/26 16:12:11 d2.utils.events]:  eta: 0:08:57  iter: 179  total_loss: 2.153  loss_cls: 0.4802  loss_box_reg: 0.835  loss_mask: 0.6106  loss_rpn_cls: 0.04699  loss_rpn_loc: 0.1748  validation_loss: 2.342    time: 0.6548  last_time: 0.6600  data_time: 0.0053  last_data_time: 0.0056   lr: 4.4955e-05  max_mem: 5400M
# [02/26 16:12:24 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 16:12:24 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 16:12:24 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/26 16:12:24 d2.data.common]: Serialized dataset takes 0.21 MiB
# [02/26 16:12:24 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/26 16:12:32 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0007 s/iter. Inference: 0.1191 s/iter. Eval: 0.5802 s/iter. Total: 0.6999 s/iter. ETA=0:00:27
# [02/26 16:12:37 d2.evaluation.evaluator]: Inference done 19/50. Dataloading: 0.0008 s/iter. Inference: 0.1235 s/iter. Eval: 0.5666 s/iter. Total: 0.6910 s/iter. ETA=0:00:21
# [02/26 16:12:43 d2.evaluation.evaluator]: Inference done 27/50. Dataloading: 0.0009 s/iter. Inference: 0.1223 s/iter. Eval: 0.5696 s/iter. Total: 0.6928 s/iter. ETA=0:00:15
# [02/26 16:12:48 d2.evaluation.evaluator]: Inference done 35/50. Dataloading: 0.0009 s/iter. Inference: 0.1202 s/iter. Eval: 0.5542 s/iter. Total: 0.6754 s/iter. ETA=0:00:10
# [02/26 16:12:53 d2.evaluation.evaluator]: Inference done 44/50. Dataloading: 0.0009 s/iter. Inference: 0.1189 s/iter. Eval: 0.5409 s/iter. Total: 0.6609 s/iter. ETA=0:00:03
# [02/26 16:12:57 d2.evaluation.evaluator]: Total inference time: 0:00:29.937618 (0.665280 s / iter per device, on 1 devices)
# [02/26 16:12:57 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:05 (0.119118 s / iter per device, on 1 devices)
# [02/26 16:12:57 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 16:12:57 d2.evaluation.coco_evaluation]: Saving results to /app/data/model/Toothsegment/version_1/eval/coco_instances_results.json
# [02/26 16:12:57 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/26 16:12:57 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/26 16:12:58 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [02/26 16:12:58 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/26 16:12:58 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.236
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.604
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.121
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.164
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.411
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.430
# [02/26 16:12:58 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 23.615 | 60.365 | 12.054 |  nan  | 16.435 | 25.289 |
# [02/26 16:12:58 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/26 16:12:58 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/26 16:12:58 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 16:12:58 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 16:12:58 d2.evaluation.testing]: copypaste: 23.6153,60.3651,12.0540,nan,16.4349,25.2888
# [02/26 16:13:02 d2.utils.events]:  eta: 0:08:45  iter: 199  total_loss: 2.061  loss_cls: 0.4545  loss_box_reg: 0.8256  loss_mask: 0.5779  loss_rpn_cls: 0.03931  loss_rpn_loc: 0.1648  validation_loss: 2.086    time: 0.6548  last_time: 0.6382  data_time: 0.0054  last_data_time: 0.0053   lr: 4.995e-05  max_mem: 5400M
# [02/26 16:13:15 d2.utils.events]:  eta: 0:08:32  iter: 219  total_loss: 2.02  loss_cls: 0.4401  loss_box_reg: 0.8186  loss_mask: 0.5568  loss_rpn_cls: 0.03836  loss_rpn_loc: 0.1671  validation_loss: 2.086    time: 0.6557  last_time: 0.7294  data_time: 0.0057  last_data_time: 0.0063   lr: 5.4945e-05  max_mem: 5400M
# [02/26 16:13:31 d2.utils.events]:  eta: 0:08:21  iter: 239  total_loss: 1.917  loss_cls: 0.4155  loss_box_reg: 0.7963  loss_mask: 0.5186  loss_rpn_cls: 0.03221  loss_rpn_loc: 0.1548  validation_loss: 2.086    time: 0.6653  last_time: 0.7856  data_time: 0.0074  last_data_time: 0.0082   lr: 5.994e-05  max_mem: 5400M
# [02/26 16:13:46 d2.utils.events]:  eta: 0:08:08  iter: 259  total_loss: 1.86  loss_cls: 0.3891  loss_box_reg: 0.7928  loss_mask: 0.481  loss_rpn_cls: 0.03616  loss_rpn_loc: 0.1541  validation_loss: 2.086    time: 0.6729  last_time: 0.7004  data_time: 0.0058  last_data_time: 0.0047   lr: 6.4935e-05  max_mem: 5405M
# [02/26 16:14:01 d2.utils.events]:  eta: 0:07:56  iter: 279  total_loss: 1.779  loss_cls: 0.365  loss_box_reg: 0.778  loss_mask: 0.4545  loss_rpn_cls: 0.02905  loss_rpn_loc: 0.1468  validation_loss: 2.086    time: 0.6779  last_time: 0.7602  data_time: 0.0052  last_data_time: 0.0053   lr: 6.993e-05  max_mem: 5405M
# [02/26 16:14:15 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 16:14:15 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 16:14:15 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/26 16:14:15 d2.data.common]: Serialized dataset takes 0.21 MiB
# [02/26 16:14:15 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/26 16:14:25 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0009 s/iter. Inference: 0.1523 s/iter. Eval: 0.7531 s/iter. Total: 0.9064 s/iter. ETA=0:00:35
# [02/26 16:14:30 d2.evaluation.evaluator]: Inference done 18/50. Dataloading: 0.0010 s/iter. Inference: 0.1457 s/iter. Eval: 0.6621 s/iter. Total: 0.8089 s/iter. ETA=0:00:25
# [02/26 16:14:36 d2.evaluation.evaluator]: Inference done 25/50. Dataloading: 0.0010 s/iter. Inference: 0.1474 s/iter. Eval: 0.6485 s/iter. Total: 0.7971 s/iter. ETA=0:00:19
# [02/26 16:14:42 d2.evaluation.evaluator]: Inference done 33/50. Dataloading: 0.0010 s/iter. Inference: 0.1430 s/iter. Eval: 0.6291 s/iter. Total: 0.7733 s/iter. ETA=0:00:13
# [02/26 16:14:47 d2.evaluation.evaluator]: Inference done 41/50. Dataloading: 0.0010 s/iter. Inference: 0.1435 s/iter. Eval: 0.6028 s/iter. Total: 0.7474 s/iter. ETA=0:00:06
# [02/26 16:14:52 d2.evaluation.evaluator]: Inference done 48/50. Dataloading: 0.0010 s/iter. Inference: 0.1412 s/iter. Eval: 0.6102 s/iter. Total: 0.7526 s/iter. ETA=0:00:01
# [02/26 16:14:54 d2.evaluation.evaluator]: Total inference time: 0:00:33.833957 (0.751866 s / iter per device, on 1 devices)
# [02/26 16:14:54 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:06 (0.140835 s / iter per device, on 1 devices)
# [02/26 16:14:54 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 16:14:54 d2.evaluation.coco_evaluation]: Saving results to /app/data/model/Toothsegment/version_1/eval/coco_instances_results.json
# [02/26 16:14:54 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/26 16:14:54 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/26 16:14:54 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [02/26 16:14:54 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/26 16:14:54 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.172
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.371
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.470
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.444
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.471
# [02/26 16:14:54 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 34.247 | 83.757 | 17.191 |  nan  | 37.111 | 34.333 |
# [02/26 16:14:54 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/26 16:14:54 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/26 16:14:54 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 16:14:54 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 16:14:54 d2.evaluation.testing]: copypaste: 34.2468,83.7568,17.1913,nan,37.1106,34.3334
# [02/26 16:14:59 d2.utils.events]:  eta: 0:07:48  iter: 299  total_loss: 1.719  loss_cls: 0.3536  loss_box_reg: 0.7624  loss_mask: 0.4326  loss_rpn_cls: 0.02528  loss_rpn_loc: 0.1595  validation_loss: 1.741    time: 0.6814  last_time: 0.7352  data_time: 0.0054  last_data_time: 0.0056   lr: 7.4925e-05  max_mem: 5405M
# [02/26 16:15:14 d2.utils.events]:  eta: 0:07:37  iter: 319  total_loss: 1.596  loss_cls: 0.3192  loss_box_reg: 0.7099  loss_mask: 0.3952  loss_rpn_cls: 0.02597  loss_rpn_loc: 0.1495  validation_loss: 1.741    time: 0.6847  last_time: 0.7262  data_time: 0.0054  last_data_time: 0.0053   lr: 7.992e-05  max_mem: 5405M
# [02/26 16:15:29 d2.utils.events]:  eta: 0:07:26  iter: 339  total_loss: 1.563  loss_cls: 0.3111  loss_box_reg: 0.6974  loss_mask: 0.3771  loss_rpn_cls: 0.02098  loss_rpn_loc: 0.1448  validation_loss: 1.741    time: 0.6883  last_time: 0.7355  data_time: 0.0056  last_data_time: 0.0051   lr: 8.4915e-05  max_mem: 5405M
# [02/26 16:15:44 d2.utils.events]:  eta: 0:07:13  iter: 359  total_loss: 1.454  loss_cls: 0.2944  loss_box_reg: 0.6589  loss_mask: 0.3655  loss_rpn_cls: 0.0261  loss_rpn_loc: 0.1432  validation_loss: 1.741    time: 0.6913  last_time: 0.7476  data_time: 0.0053  last_data_time: 0.0055   lr: 8.991e-05  max_mem: 5405M
# [02/26 16:15:58 d2.utils.events]:  eta: 0:07:01  iter: 379  total_loss: 1.463  loss_cls: 0.29  loss_box_reg: 0.6467  loss_mask: 0.363  loss_rpn_cls: 0.02138  loss_rpn_loc: 0.1448  validation_loss: 1.741    time: 0.6935  last_time: 0.7310  data_time: 0.0052  last_data_time: 0.0051   lr: 9.4905e-05  max_mem: 5405M
# [02/26 16:16:13 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 16:16:13 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 16:16:13 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/26 16:16:13 d2.data.common]: Serialized dataset takes 0.21 MiB
# [02/26 16:16:13 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/26 16:16:21 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0007 s/iter. Inference: 0.1258 s/iter. Eval: 0.5718 s/iter. Total: 0.6983 s/iter. ETA=0:00:27
# ...
# [02/26 16:22:22 d2.utils.events]:  eta: 0:03:05  iter: 739  total_loss: 1.146  loss_cls: 0.2387  loss_box_reg: 0.4843  loss_mask: 0.3059  loss_rpn_cls: 0.007975  loss_rpn_loc: 0.1203  validation_loss: 1.308    time: 0.7211  last_time: 0.6825  data_time: 0.0056  last_data_time: 0.0058   lr: 0.00018482  max_mem: 5405M
# [02/26 16:22:36 d2.utils.events]:  eta: 0:02:50  iter: 759  total_loss: 1.144  loss_cls: 0.2369  loss_box_reg: 0.4684  loss_mask: 0.3063  loss_rpn_cls: 0.005558  loss_rpn_loc: 0.1378  validation_loss: 1.308    time: 0.7205  last_time: 0.6823  data_time: 0.0053  last_data_time: 0.0052   lr: 0.00018981  max_mem: 5405M
# [02/26 16:22:50 d2.utils.events]:  eta: 0:02:36  iter: 779  total_loss: 1.161  loss_cls: 0.2433  loss_box_reg: 0.4769  loss_mask: 0.3074  loss_rpn_cls: 0.009083  loss_rpn_loc: 0.1258  validation_loss: 1.308    time: 0.7200  last_time: 0.6858  data_time: 0.0054  last_data_time: 0.0054   lr: 0.00019481  max_mem: 5405M
# [02/26 16:23:04 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 16:23:04 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 16:23:04 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/26 16:23:04 d2.data.common]: Serialized dataset takes 0.21 MiB
# [02/26 16:23:04 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/26 16:23:08 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0008 s/iter. Inference: 0.0954 s/iter. Eval: 0.2700 s/iter. Total: 0.3662 s/iter. ETA=0:00:14
# [02/26 16:23:14 d2.evaluation.evaluator]: Inference done 26/50. Dataloading: 0.0010 s/iter. Inference: 0.0962 s/iter. Eval: 0.2532 s/iter. Total: 0.3505 s/iter. ETA=0:00:08
# [02/26 16:23:19 d2.evaluation.evaluator]: Inference done 43/50. Dataloading: 0.0010 s/iter. Inference: 0.0943 s/iter. Eval: 0.2370 s/iter. Total: 0.3324 s/iter. ETA=0:00:02
# [02/26 16:23:21 d2.evaluation.evaluator]: Total inference time: 0:00:15.079610 (0.335102 s / iter per device, on 1 devices)
# [02/26 16:23:21 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:04 (0.094766 s / iter per device, on 1 devices)
# [02/26 16:23:21 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 16:23:21 d2.evaluation.coco_evaluation]: Saving results to /app/data/model/Toothsegment/version_1/eval/coco_instances_results.json
# [02/26 16:23:21 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/26 16:23:21 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/26 16:23:21 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [02/26 16:23:21 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/26 16:23:21 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.482
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.474
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.485
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.578
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.493
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.584
# [02/26 16:23:21 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 48.169 | 92.448 | 44.519 |  nan  | 47.366 | 48.475 |
# [02/26 16:23:21 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/26 16:23:21 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/26 16:23:21 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 16:23:21 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 16:23:21 d2.evaluation.testing]: copypaste: 48.1691,92.4481,44.5186,nan,47.3662,48.4751
# [02/26 16:23:26 d2.utils.events]:  eta: 0:02:21  iter: 799  total_loss: 1.16  loss_cls: 0.2429  loss_box_reg: 0.4618  loss_mask: 0.3006  loss_rpn_cls: 0.01084  loss_rpn_loc: 0.1287  validation_loss: 1.3    time: 0.7195  last_time: 0.6821  data_time: 0.0061  last_data_time: 0.0053   lr: 0.0001998  max_mem: 5405M
# [02/26 16:23:40 d2.utils.events]:  eta: 0:02:07  iter: 819  total_loss: 1.212  loss_cls: 0.2389  loss_box_reg: 0.5065  loss_mask: 0.3227  loss_rpn_cls: 0.009817  loss_rpn_loc: 0.1339  validation_loss: 1.3    time: 0.7190  last_time: 0.6834  data_time: 0.0056  last_data_time: 0.0052   lr: 0.0002048  max_mem: 5405M
# [02/26 16:23:55 d2.utils.events]:  eta: 0:01:53  iter: 839  total_loss: 1.085  loss_cls: 0.2342  loss_box_reg: 0.4358  loss_mask: 0.2896  loss_rpn_cls: 0.005833  loss_rpn_loc: 0.121  validation_loss: 1.3    time: 0.7188  last_time: 0.7588  data_time: 0.0051  last_data_time: 0.0048   lr: 0.00020979  max_mem: 5405M
# [02/26 16:24:09 d2.utils.events]:  eta: 0:01:39  iter: 859  total_loss: 1.162  loss_cls: 0.2448  loss_box_reg: 0.4708  loss_mask: 0.3036  loss_rpn_cls: 0.007648  loss_rpn_loc: 0.1376  validation_loss: 1.3    time: 0.7192  last_time: 0.7643  data_time: 0.0057  last_data_time: 0.0059   lr: 0.00021479  max_mem: 5405M
# [02/26 16:24:25 d2.utils.events]:  eta: 0:01:25  iter: 879  total_loss: 1.09  loss_cls: 0.2222  loss_box_reg: 0.4389  loss_mask: 0.2871  loss_rpn_cls: 0.004344  loss_rpn_loc: 0.1192  validation_loss: 1.3    time: 0.7203  last_time: 0.9505  data_time: 0.0054  last_data_time: 0.0064   lr: 0.00021978  max_mem: 5405M
# [02/26 16:24:40 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 16:24:40 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 16:24:40 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/26 16:24:40 d2.data.common]: Serialized dataset takes 0.21 MiB
# [02/26 16:24:40 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/26 16:24:44 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0007 s/iter. Inference: 0.0926 s/iter. Eval: 0.2381 s/iter. Total: 0.3315 s/iter. ETA=0:00:12
# [02/26 16:24:49 d2.evaluation.evaluator]: Inference done 28/50. Dataloading: 0.0010 s/iter. Inference: 0.0941 s/iter. Eval: 0.2164 s/iter. Total: 0.3115 s/iter. ETA=0:00:06
# [02/26 16:24:54 d2.evaluation.evaluator]: Inference done 45/50. Dataloading: 0.0010 s/iter. Inference: 0.0953 s/iter. Eval: 0.2127 s/iter. Total: 0.3091 s/iter. ETA=0:00:01
# [02/26 16:24:56 d2.evaluation.evaluator]: Total inference time: 0:00:14.079972 (0.312888 s / iter per device, on 1 devices)
# [02/26 16:24:56 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:04 (0.097439 s / iter per device, on 1 devices)
# [02/26 16:24:56 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 16:24:56 d2.evaluation.coco_evaluation]: Saving results to /app/data/model/Toothsegment/version_1/eval/coco_instances_results.json
# [02/26 16:24:56 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/26 16:24:56 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/26 16:24:56 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [02/26 16:24:56 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/26 16:24:56 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.483
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.926
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.438
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.447
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.488
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.581
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.590
# [02/26 16:24:56 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 48.326 | 92.640 | 43.771 |  nan  | 44.747 | 48.804 |
# [02/26 16:24:56 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/26 16:24:56 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/26 16:24:56 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 16:24:56 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 16:24:56 d2.evaluation.testing]: copypaste: 48.3258,92.6396,43.7710,nan,44.7474,48.8040
# [02/26 16:25:01 d2.utils.events]:  eta: 0:01:10  iter: 899  total_loss: 1.137  loss_cls: 0.2345  loss_box_reg: 0.4581  loss_mask: 0.305  loss_rpn_cls: 0.005134  loss_rpn_loc: 0.1273  validation_loss: 1.309    time: 0.7213  last_time: 0.7815  data_time: 0.0053  last_data_time: 0.0058   lr: 0.00022478  max_mem: 5405M
# [02/26 16:25:16 d2.utils.events]:  eta: 0:00:56  iter: 919  total_loss: 1.13  loss_cls: 0.2291  loss_box_reg: 0.453  loss_mask: 0.2949  loss_rpn_cls: 0.007194  loss_rpn_loc: 0.1289  validation_loss: 1.309    time: 0.7221  last_time: 0.7491  data_time: 0.0054  last_data_time: 0.0051   lr: 0.00022977  max_mem: 5405M
# [02/26 16:25:33 d2.utils.events]:  eta: 0:00:42  iter: 939  total_loss: 1.116  loss_cls: 0.2284  loss_box_reg: 0.4686  loss_mask: 0.2913  loss_rpn_cls: 0.005934  loss_rpn_loc: 0.122  validation_loss: 1.309    time: 0.7242  last_time: 0.7941  data_time: 0.0053  last_data_time: 0.0053   lr: 0.00023477  max_mem: 5405M
# [02/26 16:25:47 d2.utils.events]:  eta: 0:00:28  iter: 959  total_loss: 1.174  loss_cls: 0.2385  loss_box_reg: 0.4806  loss_mask: 0.3082  loss_rpn_cls: 0.007592  loss_rpn_loc: 0.1292  validation_loss: 1.309    time: 0.7242  last_time: 0.7785  data_time: 0.0054  last_data_time: 0.0055   lr: 0.00023976  max_mem: 5405M
# [02/26 16:26:02 d2.utils.events]:  eta: 0:00:14  iter: 979  total_loss: 1.062  loss_cls: 0.2319  loss_box_reg: 0.4356  loss_mask: 0.2893  loss_rpn_cls: 0.004392  loss_rpn_loc: 0.1302  validation_loss: 1.309    time: 0.7241  last_time: 0.7053  data_time: 0.0056  last_data_time: 0.0051   lr: 0.00024476  max_mem: 5405M
# [02/26 16:26:22 d2.utils.events]:  eta: 0:00:00  iter: 999  total_loss: 1.115  loss_cls: 0.2257  loss_box_reg: 0.4669  loss_mask: 0.2882  loss_rpn_cls: 0.004238  loss_rpn_loc: 0.1232  validation_loss: 1.296    time: 0.7243  last_time: 0.6941  data_time: 0.0052  last_data_time: 0.0047   lr: 0.00024975  max_mem: 5405M
# [02/26 16:26:23 d2.engine.hooks]: Overall training speed: 998 iterations in 0:12:02 (0.7243 s / it)
# [02/26 16:26:23 d2.engine.hooks]: Total training time: 0:16:48 (0:04:45 on hooks)
# [02/26 16:26:23 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 16:26:23 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 16:26:23 d2.data.common]: Serializing 50 elements to byte tensors and concatenating them all ...
# [02/26 16:26:23 d2.data.common]: Serialized dataset takes 0.21 MiB
# [02/26 16:26:23 d2.evaluation.evaluator]: Start inference on 50 batches
# [02/26 16:26:26 d2.evaluation.evaluator]: Inference done 11/50. Dataloading: 0.0007 s/iter. Inference: 0.0902 s/iter. Eval: 0.2321 s/iter. Total: 0.3230 s/iter. ETA=0:00:12
# [02/26 16:26:32 d2.evaluation.evaluator]: Inference done 28/50. Dataloading: 0.0009 s/iter. Inference: 0.0900 s/iter. Eval: 0.2166 s/iter. Total: 0.3075 s/iter. ETA=0:00:06
# [02/26 16:26:37 d2.evaluation.evaluator]: Inference done 46/50. Dataloading: 0.0009 s/iter. Inference: 0.0890 s/iter. Eval: 0.2078 s/iter. Total: 0.2978 s/iter. ETA=0:00:01
# [02/26 16:26:38 d2.evaluation.evaluator]: Total inference time: 0:00:13.476785 (0.299484 s / iter per device, on 1 devices)
# [02/26 16:26:38 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:04 (0.089150 s / iter per device, on 1 devices)
# [02/26 16:26:38 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 16:26:38 d2.evaluation.coco_evaluation]: Saving results to /app/data/model/Toothsegment/version_1/eval/coco_instances_results.json
# [02/26 16:26:38 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/26 16:26:38 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/26 16:26:38 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [02/26 16:26:38 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/26 16:26:38 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.492
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.929
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.454
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.505
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.494
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.220
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.585
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.522
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.590
# [02/26 16:26:38 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 49.187 | 92.939 | 45.430 |  nan  | 50.502 | 49.429 |
# [02/26 16:26:38 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/26 16:26:38 d2.engine.defaults]: Evaluation results for dentex_val in csv format:
# [02/26 16:26:38 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 16:26:38 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 16:26:38 d2.evaluation.testing]: copypaste: 49.1872,92.9390,45.4298,nan,50.5018,49.4292
